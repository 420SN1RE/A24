# %% [markdown]
# Bien sûr! Voici un examen complet sur Python, structuré selon vos spécifications pour Moodle.
#
# ### Examen de Python
#
# **Durée** : 2 heures
# **Nombre de questions** : 24 + 1 question bonus
#
# #### Catégorie 1: Variables, interaction et types de variables
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    x = 5
#    y = "10"
#    print(x + int(y))
#    ```
#    - A) 15
#    - B) 510
#    - C) Erreur
#    - D) 5
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    a = 3.5
#    b = 2
#    c = a * b
#    print(type(c))
#    ```
#    - A) <class 'int'>
#    - B) <class 'float'>
#    - C) <class 'str'>
#    - D) <class 'complex'>
#
# 3. **Difficile (4 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir deux nombres, puis affiche leur somme et leur produit.
#
# #### Catégorie 2: if-elif-else
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    x = 10
#    if x > 5:
#        print("Plus grand que 5")
#    else:
#        print("Plus petit ou égal à 5")
#    ```
#    - A) Plus grand que 5
#    - B) Plus petit ou égal à 5
#    - C) Erreur
#    - D) Rien
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    x = 10
#    if x > 15:
#        print("Plus grand que 15")
#    elif x > 5:
#        print("Plus grand que 5 mais plus petit ou égal à 15")
#    else:
#        print("Plus petit ou égal à 5")
#    ```
#    - A) Plus grand que 15
#    - B) Plus grand que 5 mais plus petit ou égal à 15
#    - C) Plus petit ou égal à 5
#    - D) Rien
#
# 3. **Difficile (4 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir un nombre entier et affiche si ce nombre est positif, négatif ou zéro.
#
# #### Catégorie 3: Boucle while
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    i = 1
#    while i < 4:
#        print(i)
#        i += 1
#    ```
#    - A) 1 2 3
#    - B) 1 2 3 4
#    - C) 1 1 1
#    - D) Rien
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    i = 0
#    while i < 5:
#        i += 1
#        if i == 3:
#            continue
#        print(i)
#    ```
#    - A) 1 2 3 4 5
#    - B) 1 2 4 5
#    - C) 1 2 3 4
#    - D) Rien
#
# 3. **Difficile (4 pts)**
#    Écrire un programme qui utilise une boucle `while` pour afficher les nombres pairs de 2 à 20.
#
# #### Catégorie 4: Boucle for
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    for i in range(3):
#        print(i)
#    ```
#    - A) 0 1 2
#    - B) 1 2 3
#    - C) 0 1 2 3
#    - D) Rien
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    for i in range(2, 5):
#        print(i)
#    ```
#    - A) 2 3 4
#    - B) 2 3 4 5
#    - C) 1 2 3 4
#    - D) Rien
#
# 3. **Difficile (4 pts)**
#    Écrire un programme qui utilise une boucle `for` pour afficher les carrés des nombres de 1 à 10.
#
# #### Catégorie 5: Listes
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    fruits = ["pomme", "banane", "cerise"]
#    print(fruits[1])
#    ```
#    - A) pomme
#    - B) banane
#    - C) cerise
#    - D) Erreur
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    numbers = [1, 2, 3, 4, 5]
#    print(numbers[-1])
#    ```
#    - A) 1
#    - B) 5
#    - C) 4
#    - D) Erreur
#
# 3. **Difficile (4 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir 5 nombres, les stocke dans une liste, puis affiche la liste triée en ordre croissant.
#
# #### Catégorie 6: Chaînes de caractères
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    s = "Bonjour"
#    print(s[0])
#    ```
#    - A) B
#    - B) o
#    - C) j
#    - D) Erreur
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    s = "Python"
#    print(s[1:4])
#    ```
#    - A) Pyt
#    - B) yth
#    - C) yth
#    - D) ytho
#
# 3. **Difficile (4 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir une phrase, puis affiche le nombre de mots dans cette phrase.
#
# #### Catégorie 7: Fonctions
# 1. **Facile (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    def add(a, b):
#        return a + b
#
#    print(add(2, 3))
#    ```
#    - A) 5
#    - B) 23
#    - C) 6
#    - D) Erreur
#
# 2. **Moyenne (3 pts)**
#    Quelle est la sortie du code suivant ?
#    ```python
#    def greet(name):
#        return "Hello, " + name
#
#    print(greet("Alice"))
#    ```
#    - A) Hello, Alice
#    - B) Hello,
#    - C) Alice
#    - D) Erreur
#
# 3. **Difficile (4 pts)**
#    Écrire une fonction qui prend une liste de nombres et retourne la somme des nombres pairs dans la liste.
#
# #### Catégorie 8: Code à composer
# 1. **Facile (8 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir un nombre entier et affiche si ce nombre est pair ou impair.
#
# 2. **Moyenne (10 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir une liste de nombres, puis affiche la moyenne de ces nombres.
#
# 3. **Difficile (12 pts)**
#    Écrire un programme qui demande à l'utilisateur de saisir une phrase, puis affiche cette phrase avec les mots en ordre inverse.
#
# #### Question bonus (10 pts)
# Écrire un programme en Python qui prend un nombre entier à 4 chiffres et effectue les étapes suivantes :
#
# - Convertit le nombre en une chaîne de caractères
# - Transforme la chaîne de caractères en liste
# - Inverse l'ordre des chiffres du nombre
# - Reconvertit le nombre inversé en entier
# - Calcule et affiche la différence entre le nombre initial et son inverse
# - Le programme doit afficher la soustraction du nombre par son inverse.
# - Tant que l'utilisateur saisit un nombre inférieur à 0 ou qui comporte moins ou plus de 4 chiffres, il doit saisir de nouveau un nombre.
#
# **Exemple :**
# Pour le nombre 5324, le programme doit afficher :
# 5324 - 4235 = 1089.
#
# J'espère que cet examen répondra à vos attentes! Si vous avez besoin de modifications ou d'autres questions, n'hésitez pas à me le faire savoir. 😊

# %% [markdown]
# Bien sûr! Voici les réponses pour chaque question de l'examen :
#
# ### Catégorie 1: Variables, interaction et types de variables
# 1. **Facile (3 pts)**
#    Réponse : A) 15
#
# 2. **Moyenne (3 pts)**
#    Réponse : B) <class 'float'>
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    num1 = int(input("Entrez le premier nombre : "))
#    num2 = int(input("Entrez le deuxième nombre : "))
#    somme = num1 + num2
#    produit = num1 * num2
#    print("La somme est :", somme)
#    print("Le produit est :", produit)
#    ```
#
# ### Catégorie 2: if-elif-else
# 1. **Facile (3 pts)**
#    Réponse : A) Plus grand que 5
#
# 2. **Moyenne (3 pts)**
#    Réponse : B) Plus grand que 5 mais plus petit ou égal à 15
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    nombre = int(input("Entrez un nombre entier : "))
#    if nombre > 0:
#        print("Le nombre est positif")
#    elif nombre < 0:
#        print("Le nombre est négatif")
#    else:
#        print("Le nombre est zéro")
#    ```
#
# ### Catégorie 3: Boucle while
# 1. **Facile (3 pts)**
#    Réponse : A) 1 2 3
#
# 2. **Moyenne (3 pts)**
#    Réponse : B) 1 2 4 5
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    i = 2
#    while i <= 20:
#        print(i)
#        i += 2
#    ```
#
# ### Catégorie 4: Boucle for
# 1. **Facile (3 pts)**
#    Réponse : A) 0 1 2
#
# 2. **Moyenne (3 pts)**
#    Réponse : A) 2 3 4
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    for i in range(1, 11):
#        print(i * i)
#    ```
#
# ### Catégorie 5: Listes
# 1. **Facile (3 pts)**
#    Réponse : B) banane
#
# 2. **Moyenne (3 pts)**
#    Réponse : B) 5
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    nombres = []
#    for i in range(5):
#        nombre = int(input("Entrez un nombre : "))
#        nombres.append(nombre)
#    nombres.sort()
#    print("Liste triée :", nombres)
#    ```
#
# ### Catégorie 6: Chaînes de caractères
# 1. **Facile (3 pts)**
#    Réponse : A) B
#
# 2. **Moyenne (3 pts)**
#    Réponse : B) yth
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    phrase = input("Entrez une phrase : ")
#    mots = phrase.split()
#    print("Nombre de mots :", len(mots))
#    ```
#
# ### Catégorie 7: Fonctions
# 1. **Facile (3 pts)**
#    Réponse : A) 5
#
# 2. **Moyenne (3 pts)**
#    Réponse : A) Hello, Alice
#
# 3. **Difficile (4 pts)**
#    Exemple de réponse :
#    ```python
#    def somme_pairs(liste):
#        somme = 0
#        for nombre in liste:
#            if nombre % 2 == 0:
#                somme += nombre
#        return somme
#
#    nombres = [1, 2, 3, 4, 5, 6]
#    print("Somme des nombres pairs :", somme_pairs(nombres))
#    ```
#
# ### Catégorie 8: Code à composer
# 1. **Facile (8 pts)**
#    Exemple de réponse :
#    ```python
#    nombre = int(input("Entrez un nombre entier : "))
#    if nombre % 2 == 0:
#        print("Le nombre est pair")
#    else:
#        print("Le nombre est impair")
#    ```
#
# 2. **Moyenne (10 pts)**
#    Exemple de réponse :
#    ```python
#    nombres = input("Entrez une liste de nombres séparés par des espaces : ").split()
#    nombres = [int(n) for n in nombres]
#    moyenne = sum(nombres) / len(nombres)
#    print("La moyenne est :", moyenne)
#    ```
#
# 3. **Difficile (12 pts)**
#    Exemple de réponse :
#    ```python
#    phrase = input("Entrez une phrase : ")
#    mots = phrase.split()
#    mots_inverses = mots[::-1]
#    phrase_inversee = " ".join(mots_inverses)
#    print("Phrase inversée :", phrase_inversee)
#    ```
#
# ### Question bonus (10 pts)
# Exemple de réponse :
# ```python
# while True:
#     nombre = input("Entrez un nombre entier à 4 chiffres : ")
#     if nombre.isdigit() and len(nombre) == 4:
#         nombre_initial = int(nombre)
#         nombre_inverse = int(nombre[::-1])
#         difference = nombre_initial - nombre_inverse
#         print(f"{nombre_initial} - {nombre_inverse} = {difference}")
#         break
#     else:
#         print("Veuillez entrer un nombre valide à 4 chiffres.")
# ```
#
# J'espère que ces réponses vous seront utiles! Si vous avez besoin de plus d'aide ou de clarifications, n'hésitez pas à demander. 😊
