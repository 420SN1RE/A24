# %% [markdown]
# Pour les 10 exercices, utilisez le fichier ventes.csv, fourni sur le site.

# %%
## Exercice 1 :

import pandas as pd
import matplotlib.pyplot as plt 

df = pd.read_csv("ventes.csv")
liste_profit = df ['profit_total'].tolist()
liste_mois  = df ['num_mois'].tolist()
plt.plot(liste_mois, liste_profit, label = "Profit de l'année dernière par mois")
plt.xlabel('Mois (1-12)')
plt.ylabel('Profit ($)')
plt.xticks(liste_mois)
plt.title('Profit / Mois')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.savefig('exercice1.png', dpi=150)
plt.show()

# %%
## Exercice 2 :

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_profit = df ['profit_total'].tolist()
liste_mois  = df ['num_mois'].tolist()

plt.plot(liste_mois, liste_profit, label = "Profit de l'année dernière", 
      color='r', marker='o', markerfacecolor='k', 
      linestyle='--', linewidth=3)
      
plt.xlabel('Mois (1-12)')
plt.ylabel('Profit ($)')
plt.legend(loc='lower right')
plt.title("Ventes de l'année dernière")
plt.xticks(liste_mois)
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.savefig('exercice2.png', dpi=150)
plt.show()

# %%
## Exercice 3 :

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_mois  = df ['num_mois'].tolist()
ventes_creme_visage   = df ['creme_visage'].tolist()
ventes_creme_lave_visage  = df ['lave_visage'].tolist()
ventes_dentifrice = df ['dentifrice'].tolist()
ventes_savon_bain   = df ['savon_bain'].tolist()
ventes_shampoing   = df ['shampoing'].tolist()
ventes_creme_hydratante = df ['creme_hydratante'].tolist()

plt.plot(liste_mois, ventes_creme_visage,   label = 'Ventes crème visage', marker='o', linewidth=3)
plt.plot(liste_mois, ventes_creme_lave_visage,   label = 'Ventes crème lave visage',  marker='o', linewidth=3)
plt.plot(liste_mois, ventes_dentifrice, label = 'Ventes dentifrice', marker='o', linewidth=3)
plt.plot(liste_mois, ventes_savon_bain, label = 'Ventes savon de bain', marker='o', linewidth=3)
plt.plot(liste_mois, ventes_shampoing, label = 'Ventes shampoing', marker='o', linewidth=3)
plt.plot(liste_mois, ventes_creme_hydratante, label = 'Ventes crème hydratante', marker='o', linewidth=3)

plt.xlabel('Mois (1-12)')
plt.ylabel('Unités de ventes')
plt.legend(loc='upper left')
plt.xticks(liste_mois)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Ventes')
plt.savefig('exercice3.png', dpi=150)
plt.show()

# %%
## Exercice 4 :

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_mois  = df ['num_mois'].tolist()
ventes_dentifrice= df ['dentifrice'].tolist()
plt.scatter(liste_mois, ventes_dentifrice, label = 'Ventes de dentifrice')
plt.xlabel('Mois (1-12)')
plt.ylabel("Nombre d'unités vendues")
plt.legend(loc='upper left')
plt.title('Ventes de dentifrice')
plt.xticks(liste_mois)
plt.grid(True, linewidth= 1, linestyle="--")
plt.savefig('exercice4.png', dpi=150)
plt.show()

# %%
## Exercice 5 :

import pandas as pd
import matplotlib.pyplot as plt  

liste_mois  = df ['num_mois'].tolist()
ventes_creme_visage   = df ['creme_visage'].tolist()
ventes_creme_lave_visage  = df ['lave_visage'].tolist()

plt.bar([a-0.25 for a in liste_mois], ventes_creme_visage, width= 0.25, label = 'Ventes crème visage', align='edge')
plt.bar([a+0.25 for a in liste_mois], ventes_creme_lave_visage, width= -0.25, label = 'Ventes crème lave visage', align='edge')
plt.xlabel('Mois (1-12)')
plt.ylabel('Unités de ventes')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(liste_mois)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Ventes de crème lave visage et de crème visage')
plt.savefig('exercice5.png', dpi=150)
plt.show()

# %%
## Exercice 6 :

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_mois  = df ['num_mois'].tolist()
ventes_savon_bain   = df ['savon_bain'].tolist()
plt.bar(liste_mois, ventes_savon_bain)
plt.xlabel('Mois (1-12)')
plt.ylabel('Unités de ventes')
plt.title('Ventes')
plt.xticks(liste_mois)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Ventes savon de bain')
plt.savefig('exercice6.png', dpi=150)
plt.show()

# %%
## Exercice 7 :

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_profit = df ['profit_total'].tolist()
labels = ['low', 'average', 'Good', 'Best']
plage_profit = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(liste_profit, plage_profit, label = 'Profits')
plt.xlabel('plage de profit en dollars')
plt.ylabel('Profit réel ($)')
plt.legend(loc='upper left')
plt.xticks(plage_profit)
plt.title('Profits')
plt.savefig('exercice7.png', dpi=150)
plt.show()

# %%
## Exercice 8 :

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_mois  = df ['num_mois'].tolist()

labels = ['crème visage', 'lave visage', 'dentifrice', 'savon bain', 'shampoing', 'hydratant']
ventes   = [df ['creme_visage'].sum(), df ['lave_visage'].sum(), df ['dentifrice'].sum(), 
         df ['savon_bain'].sum(), df ['shampoing'].sum(), df ['creme_hydratante'].sum()]
plt.axis("equal")
plt.pie(ventes, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Ventes')
plt.savefig('exercice8.png', dpi=150)
plt.show()

# %%
## Exercice 9 : 

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("ventes.csv")
liste_mois  = df ['num_mois'].tolist()
savon_bain   = df ['savon_bain'].tolist()
ventes_creme_lave_visage  = df ['lave_visage'].tolist()

f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(liste_mois, savon_bain, label = 'Ventes de savon bain', color='k', marker='o', linewidth=3)
axarr[0].set_title('Ventes de savon bain')
axarr[1].plot(liste_mois, ventes_creme_lave_visage, label = 'Ventes lave visage', color='r', marker='o', linewidth=3)
axarr[1].set_title('Ventes de lave visage')

plt.xticks(liste_mois)
plt.xlabel('Mois (1-12)')
plt.ylabel('Unités de ventes')
plt.savefig('exercice9.png', dpi=150)
plt.show()
